# %% [markdown]
# # Denoising with networks
#
# In this example we will denoise images of words by training a residual network.

# %% [markdown]
# ## 1. The Data
#
# the defintion of the training data generation (i.e. input/output pairs of noisy and original images), is done in ```create_samples.py```
#
# Each image is of size (w = 256, h = 72) and has a word written after which noise was added.

# %%
run create_samples.py

# %% [markdown]
# The input and output images have to be given as 4D numpy arrays (aka tensors) with the (tensorflow) convention:
#
# ```shape = (n_samples, n_height, n_width, n_channels) ```

# %%
print(X.shape)
print(Y.shape)
# Out:
# (1000, 72, 256, 1)
# (1000, 72, 256, 1)

# %% [markdown]
# ## 2. Testing the (pretrained) network
#
# The model (both a is given as an hdf5 file
#
# ```models/resunet.hdf5```

# %%
run test_net.py
# Out:
# creating samples...
# building model...
# predicting...

# %% [markdown]
# ## 3. (Re-)Training the network
#
# If one is curious, you can retrain the model instead of using the pretrained one. This may take long, however! :)

# %%
run train_net
# Out:
# creating samples...
# building model...
# training for 60 epochs...
# Train on 1800 samples, validate on 200 samples
# Epoch 1/60
#  128/1800 [=>............................] - ETA: 2806s - loss: 0.2716
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/python/zufall/train_net.py in <module>()
#      35     print("training for %s epochs..." % n_epochs)
#      36
# ---> 37     model.fit(X, Y, batch_size=64, epochs=n_epochs, validation_split=.1)
#      38
#      39     model.save_weights(fname, overwrite=True)
#
# /usr/local/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, **kwargs)
#    1496                               val_f=val_f, val_ins=val_ins, shuffle=shuffle,
# ...
